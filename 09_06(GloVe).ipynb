# %% [markdown]
# 09_06. 글로브(GloVe)

# %%
pip install glove_python_binary
# Out:
# Collecting glove_python_binary
#   Downloading glove_python_binary-0.2.0-cp37-cp37m-manylinux1_x86_64.whl (948 kB)
#      |████████████████████████████████| 948 kB 10.4 MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from glove_python_binary) (1.19.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from glove_python_binary) (1.4.1)
# Installing collected packages: glove-python-binary
# Successfully installed glove-python-binary-0.2.0

# %% [markdown]
# 데이터 불러오기

# %%
import nltk
nltk.download('punkt')

import urllib.request
import zipfile
from lxml import etree
import re
from nltk.tokenize import word_tokenize, sent_tokenize

urllib.request.urlretrieve("https://raw.githubusercontent.com/GaoleMeng/RNN-and-FFNN-textClassification/master/ted_en-20160408.xml", filename="ted_en-20160408.xml")

targetXML=open('ted_en-20160408.xml', 'r', encoding='UTF8')
# 저자의 경우 윈도우 바탕화면에서 작업하여서 'C:\Users\USER\Desktop\ted_en-20160408.xml'이 해당 파일의 경로.  
target_text = etree.parse(targetXML)
parse_text = '\n'.join(target_text.xpath('//content/text()'))
# xml 파일로부터 <content>와 </content> 사이의 내용만 가져온다.

content_text = re.sub(r'\([^)]*\)', '', parse_text)
# 정규 표현식의 sub 모듈을 통해 content 중간에 등장하는 (Audio), (Laughter) 등의 배경음 부분을 제거.
# 해당 코드는 괄호로 구성된 내용을 제거.

sent_text = sent_tokenize(content_text)
# 입력 코퍼스에 대해서 NLTK를 이용하여 문장 토큰화를 수행.

normalized_text = []
for string in sent_text:
     tokens = re.sub(r"[^a-z0-9]+", " ", string.lower())
     normalized_text.append(tokens)
# 각 문장에 대해서 구두점을 제거하고, 대문자를 소문자로 변환.

result = []
result = [word_tokenize(sentence) for sentence in normalized_text]
# 각 문장에 대해서 NLTK를 이용하여 단어 토큰화를 수행.
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %% [markdown]
# 글로브 훈련시키기

# %%
from glove import Corpus, Glove

corpus = Corpus() 
corpus.fit(result, window=5)
# 훈련 데이터로부터 GloVe에서 사용할 동시 등장 행렬 생성

glove = Glove(no_components=100, learning_rate=0.05)
glove.fit(corpus.matrix, epochs=20, no_threads=4, verbose=True)
glove.add_dictionary(corpus.dictionary)
# 학습에 이용할 쓰레드의 개수는 4로 설정, 에포크는 20.
# Out:
# Performing 20 training epochs with 4 threads
# Epoch 0
# Epoch 1
# Epoch 2
# Epoch 3
# Epoch 4
# Epoch 5
# Epoch 6
# Epoch 7
# Epoch 8
# Epoch 9
# Epoch 10
# Epoch 11
# Epoch 12
# Epoch 13
# Epoch 14
# Epoch 15
# Epoch 16
# Epoch 17
# Epoch 18
# Epoch 19

# %% [markdown]
# 결과

# %%
model_result2=glove.most_similar("boy")
print(model_result2)
# Out:
# [('girl', 0.9378614473420761), ('woman', 0.8399610428375326), ('kid', 0.8250484620763276), ('man', 0.8105895499546666)]

# %%
model_result3=glove.most_similar("university")
print(model_result3)
# Out:
# [('harvard', 0.8920739767354301), ('mit', 0.8508989982236369), ('cambridge', 0.8486340275116628), ('stanford', 0.840230310173155)]

# %%
model_result4=glove.most_similar("water")
print(model_result4)
# Out:
# [('clean', 0.8446985944687707), ('air', 0.83324867070365), ('fresh', 0.8260947622680307), ('food', 0.8200822896262302)]

# %%
model_result5=glove.most_similar("physics")
print(model_result5)
# Out:
# [('chemistry', 0.905582372343713), ('economics', 0.8873790305412815), ('beauty', 0.8732257595512711), ('mathematics', 0.8659505029377916)]

# %%
model_result6=glove.most_similar("muscle")
print(model_result6)
# Out:
# [('nerve', 0.8381578380537721), ('tissue', 0.8368249788058777), ('stem', 0.7854811954990222), ('skeletal', 0.7820435983464638)]

# %%
model_result7=glove.most_similar("clean")
print(model_result7)
# Out:
# [('water', 0.8446985944687706), ('fresh', 0.8368265180127057), ('heat', 0.8306868268171769), ('wind', 0.8148131085058221)]
