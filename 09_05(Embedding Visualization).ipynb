# %% [markdown]
# 09_05. 임베딩 벡터의 시각화(Embedding Visualization)

# %%
import os, sys 
from google.colab import drive 
drive.mount('/content/drive') 

import sys
sys.path.append('/content/drive/MyDrive/haicon') # 업로드 할 경로
print(sys.path)
# Out:
# Mounted at /content/drive
# ['', '/content', '/env/python', '/usr/lib/python37.zip', '/usr/lib/python3.7', '/usr/lib/python3.7/lib-dynload', '/usr/local/lib/python3.7/dist-packages', '/usr/lib/python3/dist-packages', '/usr/local/lib/python3.7/dist-packages/IPython/extensions', '/root/.ipython', '/content/drive/MyDrive/haicon']

# %%
# !python -m gensim.scripts.word2vec2tensor --input /content/drive/MyDrive/study/save/eng_w2v --output /content/drive/MyDrive/study/save/eng_w2v
# Out:
# 2021-09-29 06:11:19,648 - word2vec2tensor - INFO - running /usr/local/lib/python3.7/dist-packages/gensim/scripts/word2vec2tensor.py --input /content/drive/MyDrive/study/save/eng_w2v --output /content/drive/MyDrive/study/save/eng_w2v
# 2021-09-29 06:11:19,649 - utils_any2vec - INFO - loading projection weights from /content/drive/MyDrive/study/save/eng_w2v
# 2021-09-29 06:11:22,511 - utils_any2vec - INFO - loaded (21613, 100) matrix from /content/drive/MyDrive/study/save/eng_w2v
# 2021-09-29 06:11:24,566 - word2vec2tensor - INFO - 2D tensor file saved to /content/drive/MyDrive/study/save/eng_w2v_tensor.tsv
# 2021-09-29 06:11:24,568 - word2vec2tensor - INFO - Tensor metadata file saved to /content/drive/MyDrive/study/save/eng_w2v_metadata.tsv
# 2021-09-29 06:11:24,570 - word2vec2tensor - INFO - finished running word2vec2tensor.py
